# %% [markdown]
# Connected to Python 3.10.1

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv('used_car_cleaned.csv', delimiter=',')
cars.head()
cars.info()

sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2287 entries, 0 to 2286
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_brand         2287 non-null   object
#  1   car_model         2287 non-null   object
#  2   car_driven        2287 non-null   float64
#  3   car_transmission  2287 non-null   object
#  4   car_model_year    2287 non-null   int64
#  5   car_price         2287 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 107.3+ KB
# <ipython-input-1-c657a5d2bfa7>:40: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# <Axes: >

# %% [markdown]
# Connected to Python 3.10.1

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv('used_car_cleaned.csv', delimiter=',')
cars.head()
cars.info()

sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2287 entries, 0 to 2286
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_brand         2287 non-null   object
#  1   car_model         2287 non-null   object
#  2   car_driven        2287 non-null   float64
#  3   car_transmission  2287 non-null   object
#  4   car_model_year    2287 non-null   int64
#  5   car_price         2287 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 107.3+ KB
# <ipython-input-1-c657a5d2bfa7>:40: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# <Axes: >

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv('used_car_cleaned.csv', delimiter=',')
cars.head()
cars.info()

sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2287 entries, 0 to 2286
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_brand         2287 non-null   object
#  1   car_model         2287 non-null   object
#  2   car_driven        2287 non-null   float64
#  3   car_transmission  2287 non-null   object
#  4   car_model_year    2287 non-null   int64
#  5   car_price         2287 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 107.3+ KB
# <ipython-input-2-c657a5d2bfa7>:40: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# <Axes: >

# %% [markdown]
# Connected to Python 3.10.1

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
cars.head()
cars.info()

sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2287 entries, 0 to 2286
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_brand         2287 non-null   object
#  1   car_model         2287 non-null   object
#  2   car_driven        2287 non-null   float64
#  3   car_transmission  2287 non-null   object
#  4   car_model_year    2287 non-null   int64
#  5   car_price         2287 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 107.3+ KB
# <ipython-input-1-fa65b4dc8e53>:40: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# <Axes: >

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
cars.head()
cars.info()

sns.heatmap(cars.corr(), annot=True, cmap='Blues')

early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
model = Sequential()

model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))

model.add(Dense(1))

#Using MAE as loss function
model.compile(optimizer='adam',loss='mean_absolute_error')
model.fit(x=X_train, 
          y=y_train.values, 
          epochs=500,
          validation_data=(X_test, y_test.values),
          verbose=1,
          batch_size=128,
          callbacks=[early_stop]
          )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2287 entries, 0 to 2286
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_brand         2287 non-null   object
#  1   car_model         2287 non-null   object
#  2   car_driven        2287 non-null   float64
#  3   car_transmission  2287 non-null   object
#  4   car_model_year    2287 non-null   int64
#  5   car_price         2287 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 107.3+ KB
# <ipython-input-2-8a32f02e7b22>:40: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\rocke\Downloads\used_cars\import pandas as pd.py in line 56
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=53'>54</a> #Using MAE as loss function
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=54'>55</a> model.compile(optimizer='adam',loss='mean_absolute_error')
# ---> <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=55'>56</a> model.fit(x=X_train,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=56'>57</a>           y=y_train.values,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=57'>58</a>           epochs=500,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=58'>59</a>           validation_data=(X_test, y_test.values),
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=59'>60</a>           verbose=1,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=60'>61</a>           batch_size=128,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=61'>62</a>           callbacks=[early_stop]
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=62'>63</a>           )
#
# NameError: name 'X_train' is not defined

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
cars.head()


sns.heatmap(cars.corr(), annot=True, cmap='Blues')

early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
model = Sequential()

model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))
model.add(Dense(267,activation='relu'))

model.add(Dense(1))

#Using MAE as loss function
model.compile(optimizer='adam',loss='mean_absolute_error')
model.fit(x=X_train, 
          y=y_train.values, 
          epochs=500,
          validation_data=(X_test, y_test.values),
          verbose=1,
          batch_size=128,
          callbacks=[early_stop]
          )
# Out:
# <ipython-input-3-d8e87e119e91>:40: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\rocke\Downloads\used_cars\import pandas as pd.py in line 56
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=53'>54</a> #Using MAE as loss function
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=54'>55</a> model.compile(optimizer='adam',loss='mean_absolute_error')
# ---> <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=55'>56</a> model.fit(x=X_train,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=56'>57</a>           y=y_train.values,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=57'>58</a>           epochs=500,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=58'>59</a>           validation_data=(X_test, y_test.values),
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=59'>60</a>           verbose=1,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=60'>61</a>           batch_size=128,
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=61'>62</a>           callbacks=[early_stop]
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=62'>63</a>           )
#
# NameError: name 'X_train' is not defined

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
cars.head()


sns.heatmap(cars.corr(), annot=True, cmap='Blues')

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
# <ipython-input-4-5ff489057151>:40: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# <Axes: >

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
print(cars.head())


sns.heatmap(cars.corr(), annot=True, cmap='Blues')

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
#     car_brand    car_model  car_driven car_transmission  car_model_year  \
# 0     Hyundai       Tucson     83491.0        Automatic            2018
# 1   Chevrolet  Trailblazer    222000.0        Automatic            2009
# 2       Great         Wall         0.0        Automatic            2022
# 3        Ford       Fusion    178000.0        Automatic            2012
# 4  Mitsubishi      Attrage     10500.0        Automatic            2020
#
#    car_price
# 0    64000.0
# 1    20000.0
# 2   135000.0
# 3    23000.0
# 4    32000.0
# <ipython-input-5-58a37581ed49>:40: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# <Axes: >

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
print(cars.head())

print(cars.loc[cars['car_price'] > 500000])

sns.heatmap(cars.corr(), annot=True, cmap='Blues')

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
#     car_brand    car_model  car_driven car_transmission  car_model_year  \
# 0     Hyundai       Tucson     83491.0        Automatic            2018
# 1   Chevrolet  Trailblazer    222000.0        Automatic            2009
# 2       Great         Wall         0.0        Automatic            2022
# 3        Ford       Fusion    178000.0        Automatic            2012
# 4  Mitsubishi      Attrage     10500.0        Automatic            2020
#
#    car_price
# 0    64000.0
# 1    20000.0
# 2   135000.0
# 3    23000.0
# 4    32000.0
#       car_brand car_model  car_driven car_transmission  car_model_year  \
# 1800     Nissan     ZX300    150000.0           Manual            2002
# 1802       Audi        A4        12.0        Automatic            2015
# 1831     Toyota      Land     75000.0        Automatic            2016
# 1865  Chevrolet     Tahoe     17000.0        Automatic            2015
# 2062      Lexus        LX      1092.0        Automatic            2016
# 2112      Lexus        LX         0.0        Automatic            2020
# 2115    Bentley  Bentayga      5000.0        Automatic            2019
# 2151    Hyundai    Tucson     40900.0        Automatic            2017
#
#        car_price
# 1800    750000.0
# 1802  50000000.0
# 1831   1000000.0
# 1865    550000.0
# 2062   1450000.0
# 2112    600000.0
# 2115    700000.0
# 2151    700000.0
# <ipython-input-6-acd203b86f5d>:41: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# <Axes: >

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
print(cars.head())

print(cars.loc[cars['car_price'] > 500000])

sns.heatmap(cars.corr(), annot=True, cmap='Blues')

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
#     car_brand    car_model  car_driven car_transmission  car_model_year  \
# 0     Hyundai       Tucson     83491.0        Automatic            2018
# 1   Chevrolet  Trailblazer    222000.0        Automatic            2009
# 2       Great         Wall         0.0        Automatic            2022
# 3        Ford       Fusion    178000.0        Automatic            2012
# 4  Mitsubishi      Attrage     10500.0        Automatic            2020
#
#    car_price
# 0    64000.0
# 1    20000.0
# 2   135000.0
# 3    23000.0
# 4    32000.0
#       car_brand car_model  car_driven car_transmission  car_model_year  \
# 1800     Nissan     ZX300    150000.0           Manual            2002
# 1802       Audi        A4        12.0        Automatic            2015
# 1831     Toyota      Land     75000.0        Automatic            2016
# 1865  Chevrolet     Tahoe     17000.0        Automatic            2015
# 2062      Lexus        LX      1092.0        Automatic            2016
# 2112      Lexus        LX         0.0        Automatic            2020
# 2115    Bentley  Bentayga      5000.0        Automatic            2019
# 2151    Hyundai    Tucson     40900.0        Automatic            2017
#
#        car_price
# 1800    750000.0
# 1802  50000000.0
# 1831   1000000.0
# 1865    550000.0
# 2062   1450000.0
# 2112    600000.0
# 2115    700000.0
# 2151    700000.0
# <ipython-input-7-acd203b86f5d>:41: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(cars.corr(), annot=True, cmap='Blues')
# <Axes: >

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
print(cars.head())

print(cars['car_brand'])

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
#     car_brand    car_model  car_driven car_transmission  car_model_year  \
# 0     Hyundai       Tucson     83491.0        Automatic            2018
# 1   Chevrolet  Trailblazer    222000.0        Automatic            2009
# 2       Great         Wall         0.0        Automatic            2022
# 3        Ford       Fusion    178000.0        Automatic            2012
# 4  Mitsubishi      Attrage     10500.0        Automatic            2020
#
#    car_price
# 0    64000.0
# 1    20000.0
# 2   135000.0
# 3    23000.0
# 4    32000.0
# 0          Hyundai
# 1        Chevrolet
# 2            Great
# 3             Ford
# 4       Mitsubishi
#            ...
# 2282           BMW
# 2283          Ford
# 2284     Chevrolet
# 2285     Chevrolet
# 2286       Hyundai
# Name: car_brand, Length: 2287, dtype: object

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
# print(cars.head())

print(cars['car_brand'])

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
# 0          Hyundai
# 1        Chevrolet
# 2            Great
# 3             Ford
# 4       Mitsubishi
#            ...
# 2282           BMW
# 2283          Ford
# 2284     Chevrolet
# 2285     Chevrolet
# 2286       Hyundai
# Name: car_brand, Length: 2287, dtype: object

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
# print(cars.head())

print(cars['car_brand'])

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
# 0          Hyundai
# 1        Chevrolet
# 2            Great
# 3             Ford
# 4       Mitsubishi
#            ...
# 2282           BMW
# 2283          Ford
# 2284     Chevrolet
# 2285     Chevrolet
# 2286       Hyundai
# Name: car_brand, Length: 2287, dtype: object

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
# print(cars.head())

brandPrice = pd.concat(cars['car_brand'], cars['car_price'])
print(brandPrice)

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
# <ipython-input-11-5e6774dba401>:39: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   brandPrice = pd.concat(cars['car_brand'], cars['car_price'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\rocke\Downloads\used_cars\import pandas as pd.py in line 39
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=35'>36</a> cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=36'>37</a> # print(cars.head())
# ---> <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=38'>39</a> brandPrice = pd.concat(cars['car_brand'], cars['car_price'])
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=39'>40</a> print(brandPrice)
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=41'>42</a> # early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=42'>43</a> # model = Sequential()
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=43'>44</a>
#    (...)
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=61'>62</a> #           callbacks=[early_stop]
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=62'>63</a> #           )
#
# File c:\Users\rocke\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=311'>312</a>     warnings.warn(
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=312'>313</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=313'>314</a>         FutureWarning,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=314'>315</a>         stacklevel=find_stack_level(inspect.currentframe()),
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=315'>316</a>     )
# --> <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=316'>317</a> return func(*args, **kwargs)
#
# File c:\Users\rocke\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\concat.py:369, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=146'>147</a> @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=147'>148</a> def concat(
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=148'>149</a>     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=157'>158</a>     copy: bool = True,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=158'>159</a> ) -> DataFrame | Series:
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=159'>160</a>     """
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=160'>161</a>     Concatenate pandas objects along a particular axis.
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=161'>162</a>
#    (...)
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=366'>367</a>     1   3   4
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=367'>368</a>     """
# --> <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=368'>369</a>     op = _Concatenator(
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=369'>370</a>         objs,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=370'>371</a>         axis=axis,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=371'>372</a>         ignore_index=ignore_index,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=372'>373</a>         join=join,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=373'>374</a>         keys=keys,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=374'>375</a>         levels=levels,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=375'>376</a>         names=names,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=376'>377</a>         verify_integrity=verify_integrity,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=377'>378</a>         copy=copy,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=378'>379</a>         sort=sort,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=379'>380</a>     )
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=381'>382</a>     return op.get_result()
#
# File c:\Users\rocke\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\concat.py:404, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=389'>390</a> def __init__(
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=390'>391</a>     self,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=391'>392</a>     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=400'>401</a>     sort=False,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=401'>402</a> ) -> None:
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=402'>403</a>     if isinstance(objs, (ABCSeries, ABCDataFrame, str)):
# --> <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=403'>404</a>         raise TypeError(
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=404'>405</a>             "first argument must be an iterable of pandas "
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=405'>406</a>             f'objects, you passed an object of type "{type(objs).__name__}"'
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=406'>407</a>         )
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=408'>409</a>     if join == "outer":
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/core/reshape/concat.py?line=409'>410</a>         self.intersect = False
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "Series"

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
# print(cars.head())

brandPrice = pd.concat(cars['car_brand'], cars['car_price'], axis=1)
print(brandPrice)

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
# <ipython-input-12-3ae380497ba7>:39: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   brandPrice = pd.concat(cars['car_brand'], cars['car_price'], axis=1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\rocke\Downloads\used_cars\import pandas as pd.py in line 39
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=35'>36</a> cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=36'>37</a> # print(cars.head())
# ---> <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=38'>39</a> brandPrice = pd.concat(cars['car_brand'], cars['car_price'], axis=1)
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=39'>40</a> print(brandPrice)
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=41'>42</a> # early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=42'>43</a> # model = Sequential()
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=43'>44</a>
#    (...)
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=61'>62</a> #           callbacks=[early_stop]
#      <a href='file:///c%3A/Users/rocke/Downloads/used_cars/import%20pandas%20as%20pd.py?line=62'>63</a> #           )
#
# File c:\Users\rocke\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=311'>312</a>     warnings.warn(
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=312'>313</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=313'>314</a>         FutureWarning,
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=314'>315</a>         stacklevel=find_stack_level(inspect.currentframe()),
#     <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=315'>316</a>     )
# --> <a href='file:///c%3A/Users/rocke/AppData/Local/Programs/Python/Python310/lib/site-packages/pandas/util/_decorators.py?line=316'>317</a> return func(*args, **kwargs)
#
# TypeError: concat() got multiple values for argument 'axis'

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
# print(cars.head())

brandPrice = pd.concat([cars['car_brand'], cars['car_price']], axis=1)
print(brandPrice)

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
#        car_brand  car_price
# 0        Hyundai    64000.0
# 1      Chevrolet    20000.0
# 2          Great   135000.0
# 3           Ford    23000.0
# 4     Mitsubishi    32000.0
# ...          ...        ...
# 2282         BMW   103000.0
# 2283        Ford   185000.0
# 2284   Chevrolet   135000.0
# 2285   Chevrolet   135000.0
# 2286     Hyundai    73000.0
#
# [2287 rows x 2 columns]

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
# print(cars.head())

brandPrice = pd.concat([cars['car_brand'], cars['car_price']], axis=1)

print(brandPrice.groupby(['car_brand']).mean())

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
#                   car_price
# car_brand
# Abarth         4.691667e+04
# Aston          2.000000e+05
# Audi           3.952615e+06
# BAIC           5.000000e+04
# BMW            7.210714e+04
# Bentley        7.000000e+05
# Cadillac       6.214286e+04
# Changan        5.500000e+04
# Chery          3.600000e+04
# Chevrolet      4.534927e+04
# Chrysler       6.828571e+04
# Citroen        1.800000e+04
# Dodge          5.620370e+04
# Fiat           6.200000e+04
# Ford           7.346474e+04
# Foton          1.650000e+04
# GAC            4.500000e+04
# GMC            6.503226e+04
# Geely          1.370000e+04
# Great          1.350000e+05
# Haval          8.740000e+04
# Honda          3.645588e+04
# Hyundai        3.669951e+04
# Infiniti       1.900000e+05
# Isuzu          2.350000e+04
# Jaguar         1.274000e+05
# Jeep           6.626923e+04
# Kenbo          2.500000e+04
# Kia            3.072065e+04
# Land           1.346923e+05
# Lexus          2.057294e+05
# Lincoln        1.441107e+05
# MG             3.842857e+04
# Maserati       8.600000e+04
# Mazda          5.875124e+04
# Mercedes-Benz  1.123913e+05
# Mercury        1.600000e+04
# Mini           6.000000e+04
# Mitsubishi     4.294118e+04
# Nissan         4.004822e+04
# Peugeot        3.050000e+04
# Porsche        6.914286e+04
# Renault        1.697143e+04
# Subaru         1.700000e+04
# Suzuki         1.887500e+04
# Toyota         4.865281e+04
# Volkswagen     2.712500e+04
# Volvo          3.533333e+04

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
# print(cars.head())

brandPrice = pd.concat([cars['car_brand'], cars['car_price']], axis=1)
print(brandPrice)
print(brandPrice.groupby(['car_brand']).mean())

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
#        car_brand  car_price
# 0        Hyundai    64000.0
# 1      Chevrolet    20000.0
# 2          Great   135000.0
# 3           Ford    23000.0
# 4     Mitsubishi    32000.0
# ...          ...        ...
# 2282         BMW   103000.0
# 2283        Ford   185000.0
# 2284   Chevrolet   135000.0
# 2285   Chevrolet   135000.0
# 2286     Hyundai    73000.0
#
# [2287 rows x 2 columns]
#                   car_price
# car_brand
# Abarth         4.691667e+04
# Aston          2.000000e+05
# Audi           3.952615e+06
# BAIC           5.000000e+04
# BMW            7.210714e+04
# Bentley        7.000000e+05
# Cadillac       6.214286e+04
# Changan        5.500000e+04
# Chery          3.600000e+04
# Chevrolet      4.534927e+04
# Chrysler       6.828571e+04
# Citroen        1.800000e+04
# Dodge          5.620370e+04
# Fiat           6.200000e+04
# Ford           7.346474e+04
# Foton          1.650000e+04
# GAC            4.500000e+04
# GMC            6.503226e+04
# Geely          1.370000e+04
# Great          1.350000e+05
# Haval          8.740000e+04
# Honda          3.645588e+04
# Hyundai        3.669951e+04
# Infiniti       1.900000e+05
# Isuzu          2.350000e+04
# Jaguar         1.274000e+05
# Jeep           6.626923e+04
# Kenbo          2.500000e+04
# Kia            3.072065e+04
# Land           1.346923e+05
# Lexus          2.057294e+05
# Lincoln        1.441107e+05
# MG             3.842857e+04
# Maserati       8.600000e+04
# Mazda          5.875124e+04
# Mercedes-Benz  1.123913e+05
# Mercury        1.600000e+04
# Mini           6.000000e+04
# Mitsubishi     4.294118e+04
# Nissan         4.004822e+04
# Peugeot        3.050000e+04
# Porsche        6.914286e+04
# Renault        1.697143e+04
# Subaru         1.700000e+04
# Suzuki         1.887500e+04
# Toyota         4.865281e+04
# Volkswagen     2.712500e+04
# Volvo          3.533333e+04

# %%
# Data Manipulation
import numpy as np 
import pandas as pd 

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#Train Test Split
from sklearn.model_selection import train_test_split

#Scaling
from sklearn.preprocessing import StandardScaler

#Models

#Shallow:
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Deep Neural Networks:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

#Evaluation
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score

cars = pd.read_csv(r'C:\Users\rocke\Downloads\used_cars\used_car_cleaned.csv', delimiter=',')
# print(cars.head())
pd.set_option('display.float_format', lambda x: '%.3f' % x)
brandPrice = pd.concat([cars['car_brand'], cars['car_price']], axis=1)
print(brandPrice)
print(brandPrice.groupby(['car_brand']).mean())

# early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
# model = Sequential()

# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))
# model.add(Dense(267,activation='relu'))

# model.add(Dense(1))

# #Using MAE as loss function
# model.compile(optimizer='adam',loss='mean_absolute_error')
# model.fit(x=X_train, 
#           y=y_train.values, 
#           epochs=500,
#           validation_data=(X_test, y_test.values),
#           verbose=1,
#           batch_size=128,
#           callbacks=[early_stop]
#           )
# Out:
#        car_brand  car_price
# 0        Hyundai  64000.000
# 1      Chevrolet  20000.000
# 2          Great 135000.000
# 3           Ford  23000.000
# 4     Mitsubishi  32000.000
# ...          ...        ...
# 2282         BMW 103000.000
# 2283        Ford 185000.000
# 2284   Chevrolet 135000.000
# 2285   Chevrolet 135000.000
# 2286     Hyundai  73000.000
#
# [2287 rows x 2 columns]
#                 car_price
# car_brand
# Abarth          46916.667
# Aston          200000.000
# Audi          3952615.385
# BAIC            50000.000
# BMW             72107.143
# Bentley        700000.000
# Cadillac        62142.857
# Changan         55000.000
# Chery           36000.000
# Chevrolet       45349.266
# Chrysler        68285.714
# Citroen         18000.000
# Dodge           56203.704
# Fiat            62000.000
# Ford            73464.743
# Foton           16500.000
# GAC             45000.000
# GMC             65032.258
# Geely           13700.000
# Great          135000.000
# Haval           87400.000
# Honda           36455.882
# Hyundai         36699.506
# Infiniti       190000.000
# Isuzu           23500.000
# Jaguar         127400.000
# Jeep            66269.231
# Kenbo           25000.000
# Kia             30720.652
# Land           134692.308
# Lexus          205729.435
# Lincoln        144110.684
# MG              38428.571
# Maserati        86000.000
# Mazda           58751.235
# Mercedes-Benz  112391.304
# Mercury         16000.000
# Mini            60000.000
# Mitsubishi      42941.176
# Nissan          40048.224
# Peugeot         30500.000
# Porsche         69142.857
# Renault         16971.429
# Subaru          17000.000
# Suzuki          18875.000
# Toyota          48652.806
# Volkswagen      27125.000
# Volvo           35333.333
